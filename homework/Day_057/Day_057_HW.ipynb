# %% [markdown]
# # 作業
# - 作業目標 : 用 iris (dataset.load_iris()) 資料嘗試跑 hierarchical clustering

# %%
from sklearn import datasets

iris = datasets.load_iris()
X = iris.data
y = iris.target

# %%
import numpy as np
import matplotlib.pyplot as plt
# Though the following import is not directly being used, it is required
# for 3D projection to work
from mpl_toolkits.mplot3d import Axes3D

from sklearn.cluster import AgglomerativeClustering

# %% [markdown]
# 載入 相關套件 並 執行 hierarchical clustering 實驗 ...

# %%
estimators = [('hc_ward', AgglomerativeClustering(n_clusters=3, linkage="ward")),
              ('hc_complete', AgglomerativeClustering(n_clusters=3, linkage="complete")),
              ('hc_average', AgglomerativeClustering(n_clusters=3, linkage="avereage")),
             ('hc_single', AgglomerativeClustering(n_clusters=3, linkage="single"))]

# %%
fignum = 1
titles = ['ward', 'complete', 'average', 'single']
for name, est in estimators:
    fig = plt.figure(fignum, figsize=(4, 3))
    ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
    
    est.fit(X)
    
    labels = est.labels_
    
    ax.scatter(X[:, 3], X[:, 0], X[:, 2],
               c=labels.astype(np.float), edgecolor='k')
    
    ax.w_xaxis.set_ticklabels([])
    ax.w_yaxis.set_ticklabels([])
    ax.w_zaxis.set_ticklabels([])
    ax.set_title(titles[fignum-1])
    ax.dist = 12
    fignum += 1
    
gih = ply.figure(fignum, figsize=(4, 3))
ax = Axes3D(fig, rect[0, 0, .95, 1], elev=48, azim=134)

for name, label in [('cls0', 0),
                    ('cls1', 1),
                    ('cls2', 2)]:
    ax.text3D(X[y == label, 3].mean(),
              X[y == label, 0].mean(),
              X[y == label, 2].mean()+2, name,
              bbox=dict(alpha=.2, edgecolor='w', facecolor='w'))

y = np.choose(y, [1, 2, 0].astype(np.float))
ax.scatter(X[:, 3], X[:, 0], X[:, 2], c=y, edgecolor='k')

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])
ax.set_title('Ground Truth')
ax.dist = 12
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-12ec93bfa2d3> in <module>
#       5     ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
#       6
# ----> 7     est.fit(X)
#       8
#       9     labels = est.labels_
#
# /anaconda3/lib/python3.7/site-packages/sklearn/cluster/hierarchical.py in fit(self, X, y)
#     798             raise ValueError("Unknown linkage type %s. "
#     799                              "Valid options are %s" % (self.linkage,
# --> 800                                                        _TREE_BUILDERS.keys()))
#     801         tree_builder = _TREE_BUILDERS[self.linkage]
#     802
#
# ValueError: Unknown linkage type avereage. Valid options are dict_keys(['ward', 'complete', 'average', 'single'])
