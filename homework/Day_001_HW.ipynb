# %% [markdown]
# ## 作業一
# #### 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
#
# > <p>我選擇 World Happiness Report https://www.kaggle.com/unsdsn/world-happiness <br>
#    「真正的笑，就是對生活樂觀，對工作快樂，對事業興奮。」— 愛因斯坦 <br>
#      對公眾利利益擁有絕大的政策引導，同時潛在對世界有著龐大貢獻。<br>
#     人生，到頭來追尋的便是那似是終途、更是旅途的 Happiness 。
# </p>
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# > <p>資料來自於 Gallup World Poll，也就是全球繁榮指數之一的「蓋洛普世界民意調查」 <br>
#      蓋洛普在每個國家約訪談1000 位居民。訪談的目標族群是所有公民中大於15 歲的非特定人口。蓋洛普以當地的語言進行訪談，以產生統計上可比較的結果。若當地電話覆蓋人口數高達80%以上，蓋洛普使用電話訪談；反之，蓋洛普面對面訪談。
#     每日在蓋洛普收集並處理完資料後，針對每位受測者的種族、性別、教育程度、年紀、性別等量化，找出哪類的人受訪的比例不均，並在接下來的調查中，非隨機的調整受訪的對象，藉以抵消並彌補不平均的狀況。<br>
#     蓋洛普民意調查的信心水準是95%。
# </p>
#
# 3. 蒐集而來的資料型態為何
#
# > <p> 結構化數值：
#     依據六大項資料：經濟、家庭、健康（醫療制度）、自由、信任（公家機關）、慷慨 <br>
#     整合計算出各個國家、區域的「快樂指數」，進而計算出「反烏托邦指數」，並進行全球快樂指數排名。<br>
# </p>
#
# 4. 這組資料想解決的問題如何評估
#
# > <p> 客觀統計出民眾心之所向。
#     為了維持客觀性和獨立性，蓋洛普決定不為付費者和任何形式的贊助者進行民調。 <br>
#     對於政治、經濟發展與策略擬定，都有一定程度的參考價值。<br>
# </p>

# %% [markdown]
# ## 作業二
# #### 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# > <p> 提升業績定義：在評等不變的前提下，收入、訂單數上升，即維持品質同時提高訂單數量，一併帶動收入上升。<br>
#       假設：相同工作時間的前提下，兩張訂單間的休息時間越低，總訂單數量越高，收入越高，因此，將兩張訂單間的休息時間盡可能下降至最低，便能達到提升業績。 <br>
# </p>
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# > <p> 資料由App統計，統計項目有工作時數、工作時間、訂單地點 <br>
# </p>
#
# 3. 蒐集而來的資料型態為何
#
# > <p> 結構化數值：
#     依據工作時數、工作時間、訂單地點，後兩者可統計出什麼時間點哪些區域為熱門區。 <br>
# </p>
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
# > <p> 假設驗證方式：司機完成訂單後，盡可能導引至該時段之「熱門區」，降低空白的等待時段，最終比較前後業績，驗證將兩張訂單間的休息時間降低是否提升業績。<br>
# </p>

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_hat):
    return ((y-y_hat)**2).mean()

# %%
def mean_absolute_error(y, y_hat):
    return (((y-y_hat)**2).mean())**0.5

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 243.168
# The Mean absolute error is 15.594
